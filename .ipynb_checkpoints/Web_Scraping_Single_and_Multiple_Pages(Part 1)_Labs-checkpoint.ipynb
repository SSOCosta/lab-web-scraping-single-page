# %% [markdown]
# # Lab | Web Scraping Single Page (GNOD part 1)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# find url and store it in a variable
url = "https://www.popvortex.com/music/charts/top-100-albums.php"

# %%
# download html with a get request
response = requests.get(url)
response.status_code # 200 status code means OK! (403 is not ok)
# Out:
# 200

# %%
# parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")
#soup

# %%
#print(soup.prettify())

# %%
soup.select("p")
# get all elements of a tag
for p in soup("p"):
    print(p.get_text())
# Out:
# The top 100 most popular and best selling hit albums downloaded on iTunes today. To listen to the music or download any of the top 100 albums you must have Apple's iTunes player installed on your system. The chart of the current top 100 albums in the USA on iTunes is updated hourly.
# The #1 most popular album on iTunes right now is Rockstar by Dolly Parton.
# Chart of the top 100 albums last updated: November, 21 2023
# Related Charts: iTunes Top New Albums  November 2023, iTunes Top 100 Songs, and iTunes Top 200 Albums
# 1
# RockstarDolly Parton
# 2
# New Blue SunAndré 3000
# 3
# HigherChris Stapleton
# 4
# CosmoOzuna
# 5
# Poet’s Resumé - EPTim McGraw
# 6
# Welcome 2 Collegrove2 Chainz & Lil Wayne
# 7
# 1989 (Taylor's Version) [Deluxe]Taylor Swift
# 8
# LoverTaylor Swift
# 9
# For All The Dogs Scary Hours EditionDrake
# 10
# ChristmasCher
# 11
# GOLDENJung Kook
# 12
# TROLLS Band Together (Original Motion Picture Soundtrack)Various Artists
# 13
# NOW That's What I Call Music! Christmas ClassicsVarious Artists
# 14
# The Hunger Games: The Ballad of Songbirds & Snakes (Music From & Inspired By)Olivia Rodrigo, Rachel Zegler & Flatland Cavalry
# 15
# LeatherCody Johnson
# 16
# Equal Strain On All PartsJimmy Buffett
# 17
# A Charlie Brown Christmas (Original 1965 TV Soundtrack) [Expanded Edition]Vince Guaraldi Trio
# 18
# Hackney DiamondsThe Rolling Stones
# 19
# Midnights (3am Edition)Taylor Swift
# 20
# Red (Taylor's Version)Taylor Swift
# 21
# Whitsitt ChapelJelly Roll
# 22
# reputationTaylor Swift
# 23
# Too Good To Be TrueRick Ross & Meek Mill
# 24
# A Philly Special ChristmasThe Philly Specials
# 25
# The Essential NOW That's What I Call ChristmasVarious Artists
# 26
# The Beatles 1967–1970 (2023 Edition) [The Blue Album]The Beatles
# 27
# Zach BryanZach Bryan
# 28
# 1989 (Taylor's Version)Taylor Swift
# 29
# The Beatles 1962–1966 (2023 Edition) [The Red Album]The Beatles
# 30
# The Maybe ManAJR
# 31
# Christmas Eve and Other StoriesTrans-Siberian Orchestra
# 32
# Fearless (Taylor's Version)Taylor Swift
# 33
# 11:11Chris Brown
# 34
# Highway DesperadoJason Aldean
# 35
# One Thing At A TimeMorgan Wallen
# 36
# Speak Now (Taylor's Version)Taylor Swift
# 37
# All I've Ever KnownAlexandra Kay
# 38
# Live in Germany 1995Garth Brooks
# 39
# Bell Bottom CountryLainey Wilson
# 40
# I've Tried Everything But Therapy (Part 1)Teddy Swims
# 41
# Lauren DaigleLauren Daigle
# 42
# Stick Season (We'll All Be Here Forever)Noah Kahan
# 43
# COAT OF MANY COLORSBrandon Lake
# 44
# Rule of Thumb: Rule 1E-40
# 45
# Wish (Original Motion Picture Soundtrack)Julia Michaels & Wish - Cast
# 46
# ChristmasMichael Bublé
# 47
# fruitcake - EPSabrina Carpenter
# 48
# Their Greatest Hits 1971-1975Eagles
# 49
# Merry ChristmasMariah Carey
# 50
# Christmas Classics (Remastered)Bing Crosby
# 51
# White ChristmasBing Crosby
# 52
# Christmas Portrait (Special Edition)Carpenters
# 53
# Dirt on My Diamonds, Vol. 1Kenny Wayne Shepherd
# 54
# The Maverick Way CompleteMaverick City Music, Chandler Moore & Naomi Raine
# 55
# ONE MORE TIME...blink-182
# 56
# Kenotic MetanoiaLacey Sturm
# 57
# TROLLS Band Together (Original Motion Picture Soundtrack) [Deluxe Edition]Various Artists
# 58
# CONTINUUM - EPVIXX
# 59
# The Christmas Song (Expanded Edition)Nat "King" Cole
# 60
# ORANGE BLOODENHYPEN
# 61
# folkloreTaylor Swift
# 62
# American HeartbreakZach Bryan
# 63
# GUTSOlivia Rodrigo
# 64
# The Taylor Swift Holiday Collection - EPTaylor Swift
# 65
# The Greatest Christmas HitsPentatonix
# 66
# That's Christmas To MePentatonix
# 67
# Chronicle: The 20 Greatest HitsCreedence Clearwater Revival
# 68
# Episode 41 - Thor’s AngelsDan Carlin
# 69
# Journey To Bethlehem (Original Motion Picture Soundtrack)The Cast Of Journey To Bethlehem
# 70
# ABBA Gold: Greatest HitsABBA
# 71
# nadie sabe lo que va a pasar mañanaBad Bunny
# 72
# Black Mona LisaBilly Porter
# 73
# The Dark Side of the MoonPink Floyd
# 74
# Starting OverChris Stapleton
# 75
# When Christmas Comes Around...Kelly Clarkson
# 76
# the recordboygenius
# 77
# Fallen (Deluxe Edition / Remastered 2023)Evanescence
# 78
# Snow WaltzLindsey Stirling
# 79
# Super NaturalThe Wilder Blue
# 80
# evermore (deluxe version)Taylor Swift
# 81
# Home Alone (Original Motion Picture Soundtrack) [Anniversary Edition]John Williams
# 82
# Christmas SongsDavid Foster & Katharine McPhee
# 83
# NostalgiaRod Wave
# 84
# Loki: Season 2 - Vol. 2 (Episodes 4-6) [Original Soundtrack]Natalie Holt
# 85
# The Birth Of A King: Live In ConcertTommee Profitt
# 86
# Scott Pilgrim Takes Off (Soundtrack from the Netflix Original Series)Anamanaguchi & Joseph Trapanese
# 87
# Greatest HitsJourney
# 88
# ROCK-STARStray Kids
# 89
# NOW That's What I Call Music! Vol. 88Various Artists
# 90
# PRESENTEJulión Álvarez y su Norteño Banda
# 91
# Hamilton: An American Musical (Original Broadway Cast Recording)Lin-Manuel Miranda, Leslie Odom, Jr., Phillipa Soo, Daveed Diggs & Christopher Jackson
# 92
# TravellerChris Stapleton
# 93
# the mockingbird & THE CROWHARDY
# 94
# folklore (deluxe version)Taylor Swift
# 95
# Greatest HitsCreed
# 96
# Midnights (The Til Dawn Edition)Taylor Swift
# 97
# After the ButterfliesQueen Naija
# 98
# With Love - EPAdam Dollar$
# 99
# The Lost Christmas EveTrans-Siberian Orchestra
# 100
# 5150Van Halen
# © Copyright 2010 - 2023 popvortex.com | Contact | Privacy Policy | iTunes® is a trademark of Apple Inc.

# %%
song_info = []

for song in soup.find_all('p', class_='title-artist'):
    song_title = song.find('cite', class_='title').get_text()
    artist_name = song.find('em', class_='artist').get_text()
    song_info.append((song_title, artist_name))

#print("Songs:", song_info)
top_chart_songs = pd.DataFrame(song_info, columns=['song_title', 'artist_name'])

top_chart_songs
# Out:
#                           song_title               artist_name
# 0                           Rockstar              Dolly Parton
# 1                       New Blue Sun                André 3000
# 2                             Higher           Chris Stapleton
# 3                              Cosmo                     Ozuna
# 4                 Poet’s Resumé - EP                Tim McGraw
# ..                               ...                       ...
# 95  Midnights (The Til Dawn Edition)              Taylor Swift
# 96             After the Butterflies               Queen Naija
# 97                    With Love - EP              Adam Dollar$
# 98            The Lost Christmas Eve  Trans-Siberian Orchestra
# 99                              5150                 Van Halen
#
# [100 rows x 2 columns]

# %%
# Song recommendation
# Get User Input
user_input_song = input("Enter a song: ")
# Convert the user input and song names to lowercase for case-insensitive comparison
user_input_song_lower = user_input_song.lower()
top_chart_songs_lower = top_chart_songs.apply(lambda x: x.str.lower())
# Check if the user-inputted song is in the top chart songs list (case-insensitive)
if user_input_song_lower in top_chart_songs_lower['song_title'].values:
    # Filter out the user-inputted song from the DataFrame
    top_chart_songs_without_input = top_chart_songs[
        top_chart_songs_lower['song_title'] != user_input_song_lower
    ]
    # Recommend a random song from the filtered DataFrame
    recommended_song = top_chart_songs_without_input.sample().squeeze()
    print(f"You might also like: {recommended_song['song_title']} by {recommended_song['artist_name']}")
else:
    print("I am sorry but we can't provide a recommendation right now.")
# Out:
# Enter a song: cosmo
# You might also like: 5150 by Van Halen

# %% [markdown]
# # Lab | Web Scraping Multiple Pages.

# %%
# Specify the URL of the webpage you want to scrape
url1 = 'https://top40weekly.com/top-100-songs-of-all-time/'

# %%
response1 = requests.get(url1)
response1.status_code # 200 status code means OK! (403 is not ok)
# Out:
# 200

# %%
new_soup = BeautifulSoup(response1.content, "html.parser")
#new_soup

# %%
new_soup.select('div > div > figure > table > tbody > tr:nth-child(16) > td:nth-child(2)')[0].get_text()
# Out:
# 'YEAH!Usher Feat. Lil Jon & LudacrisUS Release: 2004'

# %%
#print(new_soup.prettify())

# %%
# Look for the song name and artist name in the soup
def scrape_music_info(url):
    response = requests.get(url)

    if response.status_code == 200:
        new_soup = BeautifulSoup(response.text, 'html.parser')

        # Find all table rows in the provided HTML snippet
        rows = new_soup.find_all('tr')

        music_info_list = []

        for row in rows:
            # Find all cells in the current row
            cells = row.find_all('td')

            # Check if there are at least two cells in the row
            if len(cells) >= 2:
                # Extract the text content of the cells
                song_name = cells[1].get_text(strip=True)
                # Extract the artist name from the link text
                artist_name = cells[1].find('br').get_text(strip=True)  

                # Append the extracted information to the list
                music_info_list.append([song_name, artist_name])

        return music_info_list
    else:
        return None

music_info_list = scrape_music_info(url1)
music_info_list
# Out:
# [['THE TWISTChubby CheckerUS Release: 1960', ''],
#  ['SMOOTHSantanaFeat. Rob ThomasUS Release: 1999', ''],
#  ['MACK THE KNIFEBobby DarinUS Release: 1959', ''],
#  ['UPTOWN FUNK!Mark Ronson Feat. Bruno MarsUS Release: 2015', ''],
#  ['HOW DO I LIVELeann RimesUS Release: 1997', ''],
#  ['PARTY ROCK ANTHEMLMFAO Feat. Lauren Bennett & GoonRockUS Release: 2011',
#   ''],
#  ['I GOTTA FEELINGThe Black Eyed PeasUS Release: 2009', ''],
#  ['MACARENA (BAYSIDE BOYS MIX)Los Del RioUS Release: 1996', ''],
#  ['SHAPE OF YOUEd SheeranUS Release: 2017', ''],
#  ['PHYSICALOlivia Newton-JohnUS Release: 1981', ''],
#  ['YOU LIGHT UP MY LIFEDebby BooneUS Release: 1977', ''],
#  ['HEY JUDEThe BeatlesUS Release: 1968', ''],
#  ['CLOSERThe Chainsmokers Feat. HalseyUS Release: 2016', ''],
#  ['WE BELONG TOGETHERMariah CareyUS Release: 2005', ''],
#  ['UN-BREAK MY HEARTToni BraxtonUS Release: 1996', ''],
#  ['YEAH!Usher Feat. Lil Jon & LudacrisUS Release: 2004', ''],
#  ['BETTE DAVIS EYESKim CarnesUS Release: 1981', ''],
#  ['ENDLESS LOVEDiana Ross &Lionel RichieUS Release: 1981', ''],
#  ['TONIGHT’S THE NIGHT (GONNA BE ALRIGHT)Rod StewartUS Release: 1976', ''],
#  ['YOU WERE MEANT FOR ME/FOOLISH GAMESJewelUS Release: 1997', ''],
#  ['(EVERYTHING I DO) I DO IT FOR YOUBryan AdamsUS Release: 1991', ''],
#  ['I’LL MAKE LOVE TO YOUBoyz II MenUS Release: 1994', ''],
#  ['THE THEME FROM “A SUMMER PLACE”Percy Faith & His OrchestraUS Release: 1960',
#   ''],
#  ['LE FREAKChicUS Release: 1978', ''],
#  ['HOW DEEP IS YOUR LOVEBee GeesUS Release: 1977', ''],
#  ['EYE OF THE TIGERSurvivorUS Release: 1982', ''],
#  ['WE FOUND LOVERihanna Feat. Calvin HarrisUS Release: 2011', ''],
#  ['LOWFlo Rida Feat. T-PainUS Release: 2008', ''],
#  ['JUST WANT TO BE YOUR EVERYTHINGAndy GibbUS Release: 1977', ''],
#  ['TOO CLOSENextUS Release: 1998', ''],
#  ['EVERY BREATH YOU TAKEThe PoliceUS Release: 1983', ''],
#  ['SOMEBODY THAT I USED TO KNOWGotye Feat. KimbraUS Release: 2012', ''],
#  ['DESPACITOLuis Fonsi & Daddy Yankee Feat. Justin BieberUS Release: 2017',
#   ''],
#  ['FLASHDANCE… WHAT A FEELINGIrene CaraUS Release: 1983', ''],
#  ['ROLLING IN THE DEEPAdeleUS Release: 2011', ''],
#  ['TOSSIN’ AND TURNIN’Bobby LewisUS Release: 1961', ''],
#  ['THE BATTLE OF NEW ORLEANSJohnny HortonUS Release: 1959', ''],
#  ['ONE SWEET DAYMariah Carey & Boyz II MenUS Release: 1995', ''],
#  ['TRULY MADLY DEEPLYSavage GardenUS Release: 1998', ''],
#  ['SILLY LOVE SONGSWingsUS Release: 1976', ''],
#  ['LET’S GET IT ONMarvin GayeUS Release: 1976', ''],
#  ['NIGHT FEVERBee GeesUS Release: 1978', ''],
#  ['ANOTHER ONE BITES THE DUSTQueenUS Release: 1980', ''],
#  ['SAY SAY SAYPaul McCartney&Michael JacksonUS Release: 1983', ''],
#  ['HOW YOU REMIND MENickelbackUS Release: 2011', ''],
#  ['TIE A YELLOW RIBBON ROUND THE OLE OAK TREEDawn Feat. Tony OrlandoUS Release: 1973',
#   ''],
#  ['IT’S ALL IN THE GAMETommy EdwardsUS Release: 1958', ''],
#  ['I WANT TO HOLD YOUR HANDThe BeatlesUS Release: 1964', ''],
#  ['SHADOW DANCINGAndy GibbUS Release: 1978', ''],
#  ['CALL ME MAYBECarly Rae JepsenUS Release: 2012', ''],
#  ['BLURRED LINESRobin Thicke Feat. T.I. + PharrellUS Release: 2013', ''],
#  ['CANDLE IN THE WIND ‘97/SOMETHING ABOUT THE WAY YOU LOOK TONIGHTElton JohnUS Release: 1997',
#   ''],
#  ['NO ONEAlicia KeysUS Release: 2007', ''],
#  ['I WILL ALWAYS LOVE YOUWhitney HoustonUS Release: 1992', ''],
#  ['END OF THE ROADBoyz II MenUS Release: 1992', ''],
#  ['BOOM BOOM POWThe Black Eyed PeasUS Release: 2009', ''],
#  ['CALL MEBlondieUS Release: 1980', ''],
#  ['LET ME LOVE YOUMarioUS Release: 2005', ''],
#  ['STAYIN’ ALIVEBee GeesUS Release: 2008', ''],
#  ['LADYKenny RogersUS Release: 1980', ''],
#  ['TIK TOKKeShaUS Release: 2010', ''],
#  ['I’M A BELIEVERThe MonkeesUS Release: 1966', ''],
#  ['GOLD DIGGERKanye West Feat. Jamie FoxxUS Release: 2005', ''],
#  ['APOLOGIZETimbaland Feat. OneRepublicUS Release: 2007', ''],
#  ['THE SIGNAce Of BaseUS Release: 1994', ''],
#  ['CENTERFOLDThe J. Geils BandUS Release: 1982', ''],
#  ['ALL ABOUT THAT BASSMeghan TrainorUS Release: 2014', ''],
#  ['(JUST LIKE) STARTING OVERJohn LennonUS Release: 1980', ''],
#  ['ROYALSLordeUS Release: 2013', ''],
#  ['THE BOY IS MINEBrandy & MonicaUS Release: 1998', ''],
#  ['BECAUSE I LOVE YOU (THE POSTMAN SONG)Stevie BUS Release: 1990', ''],
#  ['I LOVE ROCK ’N ROLLNJoan Jett & the BlackheartsUS Release: 1982', ''],
#  ['AQUARIUS/LET THE SUNSHINE INThe 5th DimensionUS Release: 1969', ''],
#  ['WHOOMP! (THERE IT IS)Tag TeamUS Release: 1993', ''],
#  ['MOVES LIKE JAGGERMaroon 5 Feat. Christina AguileraUS Release: 2011', ''],
#  ['EBONY AND IVORYPaul McCartney &Stevie WonderUS Release: 1982', ''],
#  ['RUSH RUSHPaula AbdulUS Release: 1991', ''],
#  ['THAT’S WHAT FRIENDS ARE FORDionne & Friends (Stevie Wonder, Gladys Knight & Elton John)US Release: 1986',
#   ''],
#  ['HAPPYPharrell WilliamsUS Release: 2014', ''],
#  ['UPSIDE DOWNDiana RossUS Release: 1980', ''],
#  ['SUGAR, SUGARThe ArchiesUS Release: 1969', ''],
#  ['JUST THE WAY YOU AREBruno MarsUS Release: 2010', ''],
#  ['DILEMMANelly Feat. Kelly RowlandUS Release: 2002', ''],
#  ['I HEARD IT THROUGH THE GRAPEVINEMarvin GayeUS Release: 1968', ''],
#  ['YOU’RE STILL THE ONEShania TwainUS Release: 1998', ''],
#  ['BILLIE JEANMichael JacksonUS Release: 1983', ''],
#  ['HOT STUFFDonna SummerUS Release: 1979', ''],
#  ['ROCKSTARPost Malone Feat. 21 SavageUS Release: 2017', ''],
#  ['GANGSTA’S PARADISECoolioFeat. L.V.US Release: 1995', ''],
#  ['ABRACADABRATheSteve Miller BandUS Release: 1982', ''],
#  ['PERFECTEd SheeranUS Release: 2017', ''],
#  ['YOU’RE SO VAINCarly SimonUS Release: 1973', ''],
#  ['PLAY THAT FUNKY MUSICWild CherryUS Release: 1973', ''],
#  ['SAY YOU, SAY MELionel RichieUS Release: 1985', ''],
#  ['MY SHARONAThe KnackUS Release: 1979', ''],
#  ['ALL NIGHT LONG (ALL NIGHT)Lionel RichieUS Release: 1983', ''],
#  ['NOTHING COMPARES 2 USinead O’ConnorUS Release: 1990', ''],
#  ['I SWEARAll-4-OneUS Release: 1994', ''],
#  ['FAMILY AFFAIRMary J. BligeUS Release: 2001', ''],
#  ['WAITING FOR A GIRL LIKE YOUForeignerUS Release: 1981', '']]

# %%
import re
music_info_list = [
    '- THE TWISTChubby Checker','- SMOOTHSantanaFeat. Rob Thomas','- MACK THE KNIFEBobby Darin',
    'UPTOWN FUNK! - Mark Ronson Feat. Bruno Mars','- HOW DO I LIVELeann Rimes','- PARTY ROCK ANTHEMLMFAO Feat. Lauren Bennett & GoonRock',
    '- I GOTTA FEELINGThe Black Eyed Peas','MACARENA (BAYSIDE BOYS MIX) - Los Del Rio','- SHAPE OF YOUEd Sheeran',
    'PHYSICALOLIVIA NEWTON- - John','- YOU LIGHT UP MY LIFEDebby Boone','- HEY JUDEThe Beatles',
    '- CLOSERThe Chainsmokers Feat. Halsey','- WE BELONG TOGETHERMariah Carey','UN- - BREAK MY HEARTToni Braxton',
    'YEAH! - Usher Feat. Lil Jon & Ludacris','- BETTE DAVIS EYESKim Carnes','- ENDLESS LOVEDiana Ross &Lionel Richie',
    'TONIGHT’S THE NIGHT (GONNA BE ALRIGHT) - Rod Stewart','YOU WERE MEANT FOR ME/ - FOOLISH GAMESJewel',
    '(EVERYTHING I DO) - I DO IT FOR YOUBryan Adams','I’ - LL MAKE LOVE TO YOUBoyz II Men',
    'THE THEME FROM “A SUMMER PLACE” - Percy Faith & His Orchestra','- LE FREAKChic','- HOW DEEP IS YOUR LOVEBee Gees',
    '- EYE OF THE TIGERSurvivor','- WE FOUND LOVERihanna Feat. Calvin Harris','LOWFLO RIDA FEAT. T- - Pain',
    '- JUST WANT TO BE YOUR EVERYTHINGAndy Gibb','- TOO CLOSENext','- EVERY BREATH YOU TAKEThe Police',
    '- SOMEBODY THAT I USED TO KNOWGotye Feat. Kimbra','- DESPACITOLuis Fonsi & Daddy Yankee Feat. Justin Bieber',
    'FLASHDANCE… - WHAT A FEELINGIrene Cara','- ROLLING IN THE DEEPAdele','TOSSIN’ AND TURNIN’ - Bobby Lewis',
    '- THE BATTLE OF NEW ORLEANSJohnny Horton','- ONE SWEET DAYMariah Carey & Boyz II Men',
    '- TRULY MADLY DEEPLYSavage Garden','- SILLY LOVE SONGSWings','LET’ - S GET IT ONMarvin Gaye',
    '- NIGHT FEVERBee Gees','- ANOTHER ONE BITES THE DUSTQueen','- SAY SAY SAYPaul McCartney&Michael Jackson',
    '- HOW YOU REMIND MENickelback','- TIE A YELLOW RIBBON ROUND THE OLE OAK TREEDawn Feat. Tony Orlando',
    'IT’ - S ALL IN THE GAMETommy Edwards','- I WANT TO HOLD YOUR HANDThe Beatles',
    '- SHADOW DANCINGAndy Gibb','- CALL ME MAYBECarly Rae Jepsen','BLURRED LINESROBIN THICKE FEAT. T.I. + - Pharrell',
    'CANDLE IN THE WIND ‘97/ - SOMETHING ABOUT THE WAY YOU LOOK TONIGHTElton John','- NO ONEAlicia Keys',
    '- I WILL ALWAYS LOVE YOUWhitney Houston','- END OF THE ROADBoyz II Men','- BOOM BOOM POWThe Black Eyed Peas',
    '- CALL MEBlondie','- LET ME LOVE YOUMario','STAYIN’ - ALIVEBee Gees','- LADYKenny Rogers',
    '- TIK TOKKeSha','I’ - M A BELIEVERThe Monkees','- GOLD DIGGERKanye West Feat. Jamie Foxx',
    '- APOLOGIZETimbaland Feat. OneRepublic','- THE SIGNAce Of Base','- CENTERFOLDThe J. Geils Band',
    '- ALL ABOUT THAT BASSMeghan Trainor','(JUST LIKE) - STARTING OVERJohn Lennon','- ROYALSLorde',
    '- THE BOY IS MINEBrandy & Monica','BECAUSE I LOVE YOU (THE POSTMAN SONG) - Stevie B',
    'I LOVE ROCK ’ - N ROLLNJoan Jett & the Blackhearts','AQUARIUS/LET THE SUNSHINE INTHE 5TH - Dimension',
    'WHOOMP! (THERE IT IS) - Tag Team','MOVES LIKE JAGGERMAROON 5 - Feat. Christina Aguilera',
    '- EBONY AND IVORYPaul McCartney &Stevie Wonder','- RUSH RUSHPaula Abdul','Unknown',
    '- HAPPYPharrell Williams','- UPSIDE DOWNDiana Ross','SUGAR, - SUGARThe Archies',
    '- JUST THE WAY YOU AREBruno Mars','- DILEMMANelly Feat. Kelly Rowland','- I HEARD IT THROUGH THE GRAPEVINEMarvin Gaye',
    'YOU’ - RE STILL THE ONEShania Twain','- BILLIE JEANMichael Jackson','- HOT STUFFDonna Summer',
    'ROCKSTARPOST MALONE FEAT. 21 - Savage','GANGSTA’ - S PARADISECoolioFeat. L.V.',
    '- ABRACADABRATheSteve Miller Band','- PERFECTEd Sheeran','YOU’ - RE SO VAINCarly Simon',
    '- PLAY THAT FUNKY MUSICWild Cherry','SAY YOU, - SAY MELionel Richie','- MY SHARONAThe Knack',
    'ALL NIGHT LONG (ALL NIGHT) - Lionel Richie','NOTHING COMPARES 2 USINEAD O’ - Connor',
    'I SWEARALL-4- - One','- FAMILY AFFAIRMary J. Blige','- WAITING FOR A GIRL LIKE YOUForeigner'
]

# Because the previous list elements weren't separated clearly by song title and artist:
def separate_capitals(text):
    # Find the index where the capital letters stop being consecutive
    index = next((i for i, c in enumerate(text) if c.islower()), len(text))

    # Separate the capitals until the one before becoming lowercased
    song_title = text[:index-1].strip()
    artist = text[index-1:].strip()

    return artist, song_title

def clean_table(data):
    cleaned_data = []

    for entry in data:
        # Remove numbers and dashes at the beginning
        entry = re.sub(r'^\d+\s*-\s*', '', entry)

        # Separate Artist and Song Title
        artist, song_title = separate_capitals(entry)

        # Remove unwanted characters
        artist = re.sub(r'\W', ' ', artist)
        song_title = re.sub(r'\W', ' ', song_title)

        # Append cleaned entry to the result
        cleaned_data.append({
            'artist_name': artist.strip(),
            'song_title': song_title.strip()
        })

    return cleaned_data
# Clean the data and create the DataFrame
cleaned_data = clean_table(music_info_list)
top_chart_songs2 = pd.DataFrame(cleaned_data)
top_chart_songs2
# Out:
#                      artist_name                    song_title
# 0                 Chubby Checker                     THE TWIST
# 1        SantanaFeat  Rob Thomas                        SMOOTH
# 2                    Bobby Darin                MACK THE KNIFE
# 3   Mark Ronson Feat  Bruno Mars                   UPTOWN FUNK
# 4                    Leann Rimes                 HOW DO I LIVE
# ..                           ...                           ...
# 95                 Lionel Richie     ALL NIGHT LONG  ALL NIGHT
# 96                        Connor  NOTHING COMPARES 2 USINEAD O
# 97                           One                  I SWEARALL 4
# 98                 Mary J  Blige                 FAMILY AFFAIR
# 99                     Foreigner   WAITING FOR A GIRL LIKE YOU
#
# [100 rows x 2 columns]

# %%
# Concatenate both dataframes to a final hot song list and get the index reset
top_songs = pd.concat([top_chart_songs, top_chart_songs2]).reset_index(drop=True)
top_songs
# Out:
#                        song_title      artist_name
# 0                        Rockstar     Dolly Parton
# 1                    New Blue Sun       André 3000
# 2                          Higher  Chris Stapleton
# 3                           Cosmo            Ozuna
# 4              Poet’s Resumé - EP       Tim McGraw
# ..                            ...              ...
# 195     ALL NIGHT LONG  ALL NIGHT    Lionel Richie
# 196  NOTHING COMPARES 2 USINEAD O           Connor
# 197                  I SWEARALL 4              One
# 198                 FAMILY AFFAIR    Mary J  Blige
# 199   WAITING FOR A GIRL LIKE YOU        Foreigner
#
# [200 rows x 2 columns]

# %%
# Getting all lower str
top_songs = top_songs.applymap(lambda x: x.lower() if isinstance(x, str) else x)
top_songs
# Out:
#                        song_title      artist_name
# 0                        rockstar     dolly parton
# 1                    new blue sun       andré 3000
# 2                          higher  chris stapleton
# 3                           cosmo            ozuna
# 4              poet’s resumé - ep       tim mcgraw
# ..                            ...              ...
# 195     all night long  all night    lionel richie
# 196  nothing compares 2 usinead o           connor
# 197                  i swearall 4              one
# 198                 family affair    mary j  blige
# 199   waiting for a girl like you        foreigner
#
# [200 rows x 2 columns]

# %%
# Song recommendation
# Get User Input
user_input_song2 = input("Enter a song: ")
# Convert the user input and song names to lowercase for case-insensitive comparison
user_input_song_lower = user_input_song2.lower()
top_chart_songs_lower = top_chart_songs2.apply(lambda x: x.str.lower())
# Check if the user-inputted song is in the top chart songs list (case-insensitive)
if user_input_song_lower in top_chart_songs_lower['song_title'].values:
    # Filter out the user-inputted song from the DataFrame
    top_chart_songs_without_input = top_chart_songs2[
        top_chart_songs_lower['song_title'] != user_input_song_lower
    ]
    # Recommend a random song from the filtered DataFrame
    recommended_song = top_chart_songs_without_input.sample().squeeze()
    print(f"You might also like: {recommended_song['song_title']} by {recommended_song['artist_name']}")
else:
    print("I am sorry but we can't provide a recommendation right now.")
# Out:
# Enter a song: i swearall 4
# You might also like: NOTHING COMPARES 2 USINEAD O by Connor

# %%
#Saving the file
top_songs.to_csv('top_songs.csv', index=False)
